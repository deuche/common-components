# %% [markdown]
# <a href="https://colab.research.google.com/github/deuche/common-components/blob/master/Cubix_ML_Engineer_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandas

# %%
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
import pandas as pd

# %%
# Example 0: Creating a pandas Series
pd.Series([1, 3, 5])
# Out:
# 0    1
# 1    3
# 2    5
# dtype: int64

# %%
### Pandas DataFrame Creation Examples

# Example 1: Creating a DataFrame from a dictionary of lists
# Keys become column names. Lists must be of the same length.
data_dict = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}
df_from_dict = pd.DataFrame(data_dict)
print("DataFrame from dictionary:")
print(df_from_dict)
# Out:
# DataFrame from dictionary:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# Example 2: Creating a DataFrame from a list of dictionaries
# Each dictionary in the list represents a row. Keys become column names.
data_list_of_dicts = [
    {'A': 1, 'B': 4, 'C': 7},
    {'A': 2, 'B': 5, 'C': 8},
    {'A': 3, 'B': 6, 'C': 9}
]
df_from_list_of_dicts = pd.DataFrame(data_list_of_dicts)
print("\nDataFrame from list of dictionaries:")
print(df_from_list_of_dicts)
# Out:
# DataFrame from list of dictionaries:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
# Example 3: Creating a DataFrame using a MultiIndex
# A MultiIndex allows you to have multiple levels of indexes in rows or columns
index = pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1), ('b', 2)], names=['first', 'second'])
df_multi_index = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8]}, index=index)
print("\nDataFrame with MultiIndex:")
print(df_multi_index)
# Out:
# DataFrame with MultiIndex:
#               A  B
# first second
# a     1       1  5
#       2       2  6
# b     1       3  7
#       2       4  8

# %%
# Example 4: Creating a DataFrame from a list of lists with column names specified
# Each inner list is a row. Column names are provided separately.
data_list_of_lists = [
    [1, 4, 7],
    [2, 5, 8],
    [3, 6, 9]
]
columns = ['A', 'B', 'C']
df_from_list_of_lists = pd.DataFrame(data_list_of_lists, columns=columns)
print("\nDataFrame from list of lists with column names:")
print(df_from_list_of_lists)
# Out:
# DataFrame from list of lists with column names:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
# Example 5: Creating an empty DataFrame with column names
# Useful when you need to create a DataFrame structure to be filled later.
empty_df = pd.DataFrame(columns=['A', 'B', 'C'])
print("\nEmpty DataFrame:")
print(empty_df)
# Out:
# Empty DataFrame:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
# Load a sample dataset from seaborn library
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df["sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
df.describe() # Descriptive statistics for each column
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# Selecting a subset of the dataset for demonstration
df_subset = df[['class', 'sex', 'age', 'fare']]
df_subset
# Out:
#       class     sex   age     fare
# 0     Third    male  22.0   7.2500
# 1     First  female  38.0  71.2833
# 2     Third  female  26.0   7.9250
# 3     First  female  35.0  53.1000
# 4     Third    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886  Second    male  27.0  13.0000
# 887   First  female  19.0  30.0000
# 888   Third  female   NaN  23.4500
# 889   First    male  26.0  30.0000
# 890   Third    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
# Wide to Long
long_df = pd.melt(df_subset, id_vars=['class', 'sex'], value_vars=['age', 'fare'])
long_df
# Out:
#        class     sex variable  value
# 0      Third    male      age  22.00
# 1      First  female      age  38.00
# 2      Third  female      age  26.00
# 3      First  female      age  35.00
# 4      Third    male      age  35.00
# ...      ...     ...      ...    ...
# 1777  Second    male     fare  13.00
# 1778   First  female     fare  30.00
# 1779   Third  female     fare  23.45
# 1780   First    male     fare  30.00
# 1781   Third    male     fare   7.75
#
# [1782 rows x 4 columns]

# %%
# Long to Wide (the opposite of the last one)
wide_df = long_df.pivot_table(index=['class', 'sex'], columns='variable', values='value', aggfunc='mean')
wide_df
# Out:
# variable             age        fare
# class  sex
# First  female  34.611765  106.125798
#        male    41.281386   67.226127
# Second female  28.722973   21.970121
#        male    30.740707   19.741782
# Third  female  21.750000   16.118810
#        male    26.507589   12.661633

# %%
df_subset.head()
# Out:
#    class     sex   age     fare
# 0  Third    male  22.0   7.2500
# 1  First  female  38.0  71.2833
# 2  Third  female  26.0   7.9250
# 3  First  female  35.0  53.1000
# 4  Third    male  35.0   8.0500

# %%
# Transpose
transposed_df = df_subset.head().T
transposed_df
# Out:
#            0        1       2       3      4
# class  Third    First   Third   First  Third
# sex     male   female  female  female   male
# age     22.0     38.0    26.0    35.0   35.0
# fare    7.25  71.2833   7.925    53.1   8.05

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.iloc[10:]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 13          0       3    male  39.0      1      5  31.2750        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Concat and filtering: with particular index
pd.concat([df.iloc[100:], df.iloc[:100]])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 100         0       3  female  28.0      0      0   7.8958        S   Third
# 101         0       3    male   NaN      0      0   7.8958        S   Third
# 102         0       1    male  21.0      0      1  77.2875        S   First
# 103         0       3    male  33.0      0      0   8.6542        S   Third
# 104         0       3    male  37.0      2      0   7.9250        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# 96          0       1    male  71.0      0      0  34.6542        C   First
# 97          1       1    male  23.0      0      1  63.3583        C   First
# 98          1       2  female  34.0      0      1  23.0000        S  Second
# 99          0       2    male  34.0      1      0  26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# reset index
pd.concat([df.iloc[100:], df.iloc[:100]]).reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0      100         0       3  female  28.0      0      0   7.8958        S
# 1      101         0       3    male   NaN      0      0   7.8958        S
# 2      102         0       1    male  21.0      0      1  77.2875        S
# 3      103         0       3    male  33.0      0      0   8.6542        S
# 4      104         0       3    male  37.0      2      0   7.9250        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886     95         0       3    male   NaN      0      0   8.0500        S
# 887     96         0       1    male  71.0      0      0  34.6542        C
# 888     97         1       1    male  23.0      0      1  63.3583        C
# 889     98         1       2  female  34.0      0      1  23.0000        S
# 890     99         0       2    male  34.0      1      0  26.0000        S
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# reset index - dropping indexes from columns
concated = pd.concat([df.iloc[100:], df.iloc[:100]]).reset_index(drop=True)
concated
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  female  28.0      0      0   7.8958        S   Third
# 1           0       3    male   NaN      0      0   7.8958        S   Third
# 2           0       1    male  21.0      0      1  77.2875        S   First
# 3           0       3    male  33.0      0      0   8.6542        S   Third
# 4           0       3    male  37.0      2      0   7.9250        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       3    male   NaN      0      0   8.0500        S   Third
# 887         0       1    male  71.0      0      0  34.6542        C   First
# 888         1       1    male  23.0      0      1  63.3583        C   First
# 889         1       2  female  34.0      0      1  23.0000        S  Second
# 890         0       2    male  34.0      1      0  26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Subsets - filtering: with particular logic
concated.loc[concated["age"] < 30]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3  female  28.0      0      0   7.8958        S  Third
# 2           0       1    male  21.0      0      1  77.2875        S  First
# 5           0       3    male  28.0      0      0   7.8958        S  Third
# 6           1       3  female  21.0      0      0   7.6500        S  Third
# 11          0       3  female  14.5      1      0  14.4542        C  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 880         0       3    male  24.0      0      0   8.0500        S  Third
# 881         0       3    male  29.0      0      0   8.0500        S  Third
# 882         0       3    male  20.0      0      0   7.8542        S  Third
# 884         0       3    male  26.0      1      2  20.5750        S  Third
# 888         1       1    male  23.0      0      1  63.3583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Subsets - filtering: More than one logics are in brackets
concated.loc[(concated["age"] < 30) &
            (concated["class"] == "Third")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3  female  28.0      0      0   7.8958        S  Third
# 5           0       3    male  28.0      0      0   7.8958        S  Third
# 6           1       3  female  21.0      0      0   7.6500        S  Third
# 11          0       3  female  14.5      1      0  14.4542        C  Third
# 12          0       3    male  22.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 877         0       3    male  16.0      1      3  34.3750        S  Third
# 880         0       3    male  24.0      0      0   8.0500        S  Third
# 881         0       3    male  29.0      0      0   8.0500        S  Third
# 882         0       3    male  20.0      0      0   7.8542        S  Third
# 884         0       3    male  26.0      1      2  20.5750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.iloc[50:100]
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 50         0       3    male   7.00      4      1   39.6875        S   Third
# 51         0       3    male  21.00      0      0    7.8000        S   Third
# 52         1       1  female  49.00      1      0   76.7292        C   First
# 53         1       2  female  29.00      1      0   26.0000        S  Second
# 54         0       1    male  65.00      0      1   61.9792        C   First
# 55         1       1    male    NaN      0      0   35.5000        S   First
# 56         1       2  female  21.00      0      0   10.5000        S  Second
# 57         0       3    male  28.50      0      0    7.2292        C   Third
# 58         1       2  female   5.00      1      2   27.7500        S  Second
# 59         0       3    male  11.00      5      2   46.9000        S   Third
# 60         0       3    male  22.00      0      0    7.2292        C   Third
# ...

# %%
# Sort values
df.sort_values("age").head(50)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 827         1       2    male  1.00      0      2   37.0042        C  Second
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
print(df["age"].median())
print(df["age"].mean())
print(df["age"].min())
print(df["age"].max())
print(df["age"].sum())
# Out:
# 28.0
# 29.69911764705882
# 0.42
# 80.0
# 21205.17

# %%
df.groupby(by="class").mean()
# Out:
# <ipython-input-79-849d7e18385a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by="class").mean()
#         survived  pclass        age     sibsp     parch       fare  \
# class
# First   0.629630     1.0  38.233441  0.416667  0.356481  84.154687
# Second  0.472826     2.0  29.877630  0.402174  0.380435  20.662183
# Third   0.242363     3.0  25.140620  0.615071  0.393075  13.675550
#
#         adult_male     alone
# class
# First     0.550926  0.504630
# Second    0.538043  0.565217
# Third     0.649695  0.659878

# %%
df.sort_values(by="age")["age"].reset_index(drop=True).plot()
# Out:
# <Axes: >

# %%
df["age"].hist(bins=20)
# Out:
# <Axes: >

# %%
df["age"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.drop(columns=["age"])
# Out:
#      survived  pclass     sex  sibsp  parch     fare embarked   class    who  \
# 0           0       3    male      1      0   7.2500        S   Third    man
# 1           1       1  female      1      0  71.2833        C   First  woman
# 2           1       3  female      0      0   7.9250        S   Third  woman
# 3           1       1  female      1      0  53.1000        S   First  woman
# 4           0       3    male      0      0   8.0500        S   Third    man
# ..        ...     ...     ...    ...    ...      ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000        S  Second    man
# 887         1       1  female      0      0  30.0000        S   First  woman
# 888         0       3  female      1      2  23.4500        S   Third  woman
# 889         1       1    male      0      0  30.0000        C   First    man
# 890         0       3    male      0      0   7.7500        Q   Third    man
#
# ...

# %%
df.drop(index=[0, 1])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
